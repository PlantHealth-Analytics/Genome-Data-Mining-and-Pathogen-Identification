# %% [markdown]
# # Fastq Quality Evaluation

# %% [markdown]
# This notebook will evaluate the quality of FASTQ files generated by sequencing technologies: Illumina short reads and Nanopore long reads.

# %% [markdown]
# First, we will install the required dependencies using conda, including FastQC and NanoPlot.

# %%
# !wget -nc https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages')
# Out:
# --2025-11-05 17:10:07--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156323998 (149M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 149.08M   245MB/s    in 0.6s
#
# 2025-11-05 17:10:08 (245 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [156323998/156323998]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
#!conda create -n qcenv -y -c bioconda -c conda-forge fastqc
# Out:
# Jupyter detected...
#
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     - https://repo.anaconda.com/pkgs/main
#     - https://repo.anaconda.com/pkgs/r
#
# To accept these channels' Terms of Service, run the following commands:
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# For information on safely removing channels from your conda configuration,
# please see the official documentation:
#
#     https://www.anaconda.com/docs/tools/working-with-conda/channels

# %%
# !pip install nanoplot -q
# !apt-get install -y libfreetype6 libpng-dev
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   DEPRECATION: Building 'nanoplot' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'nanoplot'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for nanoplot (setup.py) ... done
#   DEPRECATION: Building 'nanoget' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'nanoget'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for nanoget (setup.py) ... done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libpng-dev is already the newest version (1.6.37-3build5).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %% [markdown]
# Next, we will load the Illumina short-read data into our workspace using the wget command. We will run FastQC on these reads and evaluate the results.

# %%
# !wget http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR240/022/SRR24008622/SRR24008622_1.fastq.gz	http://ftp.sra.ebi.ac.uk/vol1/fastq/SRR240/022/SRR24008622/SRR24008622_2.fastq.gz

# %%
# !apt-get update
# !apt-get install -y fastqc

# %%
# !fastqc *.fastq.gz

# %% [markdown]
# The cell below will help us to visualize the results

# %%
import os
from IPython.core.display import display, HTML

# Ask the user for the file name they want to display
file_name = input("Enter the name of the HTML file you want to display (include .html extension): ")

# Check if the file exists
if os.path.exists(file_name):
    # Open and read the HTML file
    with open(file_name, 'r') as file:
        html_content = file.read()
        display(HTML(html_content))  # Display the HTML content
else:
    print(f"File '{file_name}' not found. Please ensure the file exists in the current directory.")

# %% [markdown]
#  Now we will fetch the Nanopore long-read data using wget, run NanoPlot, and evaluate the output.

# %%
# !wget https://zenodo.org/record/14018699/files/SRR30576370.fastq.gz

# %%
# !NanoPlot --fastq SRR30576370.fastq.gz

# %% [markdown]
# The cell below will help us to visualize the results

# %%
import os
from IPython.core.display import display, HTML

# Ask the user for the file name they want to display
file_name = input("Enter the name of the HTML file you want to display (include .html extension): ")

# Check if the file exists
if os.path.exists(file_name):
    # Open and read the HTML file
    with open(file_name, 'r') as file:
        html_content = file.read()
        display(HTML(html_content))  # Display the HTML content
else:
    print(f"File '{file_name}' not found. Please ensure the file exists in the current directory.")
